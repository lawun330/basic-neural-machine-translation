# %% [markdown]
# # Neural Machine Translation Transformer (NMT Transformer) Model: Version 1
# ## Myanmar (Burmese) Language: Grapheme to Phoneme Translation

# %% [markdown]
# ## Setup

# %%
# !marian --help
# Out:
# Marian: Fast Neural Machine Translation in C++
# Usage: marian [OPTIONS]
#
# General options:
#   -h,--help                             Print this help message and exit
#   --version                             Print the version number and exit
#   --authors                             Print list of authors and exit
#   --cite                                Print citation and exit
#   --build-info TEXT                     Print CMake build options and exit. Set to 'all' to print advanced options
#   -c,--config VECTOR ...                Configuration file(s). If multiple, later overrides earlier
#   -w,--workspace INT=2048               Preallocate arg MB of work space. Negative `--workspace -N` value allocates workspace as total available GPU memory minus N megabytes.
#   --log TEXT                            Log training process information to file given by arg
# ...

# %%
from pathlib import Path
from IPython.display import Image

# %%
ROOT = Path("..").resolve()

DATA_ROOT = ROOT / "data"
DATA_DIR = DATA_ROOT / "cleaned"
VOCAB_DIR = DATA_ROOT / "vocab"
MODEL_DIR = ROOT / "models"

BLEU_DIR = "/home/lawun330/NLP/ubuntu-17.04/moses/scripts/generic"

# %% [markdown]
# ## Configurations
#
# File paths, command flags, and arguments must be updated in a bash file.

# %%
# !find {ROOT}/*.sh
# Out:
# /home/lawun330/Desktop/basic-neural-machine-translation/seq2seq.myph.sh
# /home/lawun330/Desktop/basic-neural-machine-translation/transformer.myph.sh

# %%
# !cat {ROOT}/transformer.myph.sh
# Out:
# #!/bin/bash
#
# ## Written by Ye Kyaw Thu, Affiliated Professor, CADT, Cambodia
# ## for NMT Experiments between Burmese and Ethnic Languages
# ## used Marian NMT Framework for transformer training
# ## Last updated: 23 May 2022
#
# model_folder="../models/model.transformer.myph"; # -- MODIFIED --
# mkdir ${model_folder};
# data_path="../data/cleaned"; # -- MODIFIED --
# vocab_path="../data/vocab"; # -- MODIFIED --
# src="my"; tgt="ph"; # -- MODIFIED --
#
# marian \
#   --type transformer \
#   --train-sets ${data_path}/train.${src} ${data_path}/train.${tgt} \
#   --max-length 200 \
#   --valid-sets ${data_path}/dev.${src} ${data_path}/dev.${tgt} \
#   --vocabs ${vocab_path}/vocab.${src}.yml ${vocab_path}/vocab.${tgt}.yml \
#   --maxi-batch 100 \
#   --valid-translation-output ${model_folder}/valid.output --quiet-translation \
#   --beam-size 6 --normalize 0.6 \
#   --transformer-heads 8 \
#   --transformer-postprocess-emb d \
#   --transformer-postprocess dan \
# ...

# %% [markdown]
# ## Machine Translation: Transformer Training for Grapheme to Phoneme

# %%
# check available GPU(s)
# !nvidia-smi
# Out:
# Fri May 29 14:27:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.03             Driver Version: 580.159.03     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1060        Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   73C    P5             13W /   88W |       4MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !{ROOT}/transformer.myph.sh
# Out:
# mkdir: cannot create directory ‘../models/model.transformer.myph’: File exists
# [2026-05-29 14:28:00] [marian] Marian v1.12.0 65bf82ff 2023-02-21 09:56:29 -0800
# [2026-05-29 14:28:00] [marian] Running on ROG-Strix-Hero-II as process 63371 with command line:
# [2026-05-29 14:28:00] [marian] marian -c ../models/model.transformer.myph/config.yml
# [2026-05-29 14:28:00] [config] after: 0e
# [2026-05-29 14:28:00] [config] after-batches: 0
# [2026-05-29 14:28:00] [config] after-epochs: 0
# [2026-05-29 14:28:00] [config] all-caps-every: 0
# [2026-05-29 14:28:00] [config] allow-unk: false
# [2026-05-29 14:28:00] [config] authors: false
# [2026-05-29 14:28:00] [config] beam-size: 6
# [2026-05-29 14:28:00] [config] bert-class-symbol: "[CLS]"
# [2026-05-29 14:28:00] [config] bert-mask-symbol: "[MASK]"
# [2026-05-29 14:28:00] [config] bert-masking-fraction: 0.15
# [2026-05-29 14:28:00] [config] bert-sep-symbol: "[SEP]"
# [2026-05-29 14:28:00] [config] bert-train-type-embeddings: true
# ...

# %% [markdown]
# ## Results: Config File

# %%
# !cat {MODEL_DIR}/model.transformer.myph/config.yml
# Out:
# # Marian configuration file generated at 2026-05-29 14:28:00 +0700 with version v1.12.0 65bf82ff 2023-02-21 09:56:29 -0800
# # General options
# authors: false
# cite: false
# build-info: ""
# workspace: 1000
# log: ../models/model.transformer.myph/train.log
# log-level: info
# log-time-zone: ""
# quiet: false
# quiet-translation: true
# seed: 1111
# check-nan: false
# interpolate-env-vars: false
# relative-paths: false
# sigterm: save-and-exit
# # Model options
# model: ../models/model.transformer.myph/model.npz
# pretrained-model: ""
# ignore-model-config: false
# type: transformer
# dim-vocabs:
#   - 0
#   - 0
# dim-emb: 512
# factors-dim-emb: 0
# factors-combine: sum
# lemma-dependency: ""
# lemma-dim-emb: 0
# dim-rnn: 1024
# enc-type: bidirectional
# enc-cell: gru
# enc-cell-depth: 1
# enc-depth: 2
# dec-cell: gru
# dec-cell-base-depth: 2
# dec-cell-high-depth: 1
# dec-depth: 2
# skip: false
# layer-normalization: false
# right-left: false
# input-types:
#   []
# ...

# %% [markdown]
# ## Results: Output Models

# %%
# check available models
# !ls {MODEL_DIR}/model.transformer.myph/ --color=auto
# Out:
# config.yml           model.iter40000.npz    model.npz.optimizer.npz
# model.iter10000.npz  model.iter45000.npz    model.npz.progress.yml
# model.iter15000.npz  model.iter50000.npz    model.npz.yml
# model.iter20000.npz  model.iter5000.npz     train.log
# model.iter25000.npz  model.iter55000.npz    transformer.my-ph.log
# model.iter30000.npz  model.npz              valid.log
# model.iter35000.npz  model.npz.decoder.yml  valid.output

# %%
# check best model
# !cat {MODEL_DIR}/model.transformer.myph/valid.log
# Out:
# [2026-05-29 14:52:43] [valid] Ep. 80 : Up. 5000 : cross-entropy : 1.86253 : new best
# [2026-05-29 14:52:44] [valid] Ep. 80 : Up. 5000 : perplexity : 1.62341 : new best
# [2026-05-29 14:52:44] [valid] First sentence's tokens as scored:
# [2026-05-29 14:52:44] [valid] DefaultVocab keeps original segments for scoring
# [2026-05-29 14:52:44] [valid]   Hyp: ou' ta- ra. hpa- la- gu. ni
# [2026-05-29 14:52:44] [valid]   Ref: ou' ta- ra. hpa- la. gu. ni
# [2026-05-29 14:52:48] [valid] Ep. 80 : Up. 5000 : bleu : 72.5211 : new best
# [2026-05-29 15:24:56] [valid] Ep. 160 : Up. 10000 : cross-entropy : 2.13194 : stalled 1 times (last best: 1.86253)
# [2026-05-29 15:24:57] [valid] Ep. 160 : Up. 10000 : perplexity : 1.74127 : stalled 1 times (last best: 1.62341)
# [2026-05-29 15:25:01] [valid] Ep. 160 : Up. 10000 : bleu : 74.4712 : new best
# [2026-05-29 15:52:43] [valid] Ep. 240 : Up. 15000 : cross-entropy : 2.28535 : stalled 2 times (last best: 1.86253)
# ...

# %% [markdown]
# ## Machine Translation
#
# From the results above, the best model occurs around 10,000 iterations, achieving the best BLEU score on the validation set.

# %%
# check available GPU(s)
# !nvidia-smi
# Out:
# Fri May 29 19:00:37 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.03             Driver Version: 580.159.03     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1060        Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   56C    P8             10W /   40W |       4MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# use the best model on test data to generate the hypothesis file
# !time marian-decoder -m {MODEL_DIR}/model.transformer.myph/model.iter10000.npz -v {VOCAB_DIR}/vocab.my.yml {VOCAB_DIR}/vocab.ph.yml --devices 0 < {DATA_DIR}/test.my > {DATA_DIR}/transformer.myph.hyp.txt
# Out:
# [2026-05-29 19:02:41] [marian] Marian v1.12.0 65bf82ff 2023-02-21 09:56:29 -0800
# [2026-05-29 19:02:41] [marian] Running on ROG-Strix-Hero-II as process 85263 with command line:
# [2026-05-29 19:02:41] [marian] marian-decoder -m /home/lawun330/Desktop/basic-neural-machine-translation/models/model.transformer.myph/model.iter10000.npz -v /home/lawun330/Desktop/basic-neural-machine-translation/data/vocab/vocab.my.yml /home/lawun330/Desktop/basic-neural-machine-translation/data/vocab/vocab.ph.yml --devices 0
# [2026-05-29 19:02:41] [config] alignment: ""
# [2026-05-29 19:02:41] [config] allow-special: false
# [2026-05-29 19:02:41] [config] allow-unk: false
# [2026-05-29 19:02:41] [config] authors: false
# [2026-05-29 19:02:41] [config] beam-size: 12
# [2026-05-29 19:02:41] [config] bert-class-symbol: "[CLS]"
# [2026-05-29 19:02:41] [config] bert-mask-symbol: "[MASK]"
# [2026-05-29 19:02:41] [config] bert-masking-fraction: 0.15
# [2026-05-29 19:02:41] [config] bert-sep-symbol: "[SEP]"
# ...

# %% [markdown]
# ## Model Evaluation
# ### Multi-BLEU Score

# %%
# check directory where score evaluation script lives 
# !ls {BLEU_DIR} --color=auto
# Out:
# binarize4moses2.perl    generic-parallel.perl  multi-bleu.perl
# bsbleu.py               giza-parallel.perl     multi_moses.py
# compound-splitter.perl  lopar2pos.pl           ph_numbers.perl
# extract-factors.pl      moses-parallel.pl      qsub-wrapper.pl
# extract-parallel.perl   moses_sim_pe.py        reverse-alignment.perl
# fsa2fsal.pl             mteval-v11b.pl         score-parallel.perl
# fsa2plf.pl              mteval-v12.pl          score_parallel.py
# fsal2fsa.pl             mteval-v13a.pl         strip-xml.perl
# fsa-sample.fsa          mteval-v14.pl          trainlm-irst2.perl

# %%
# compute BLEU score with the reference file
# !perl {BLEU_DIR}/multi-bleu.perl {DATA_DIR}/test.ph < {DATA_DIR}/transformer.myph.hyp.txt | tee {MODEL_DIR}/results/myph_transformer_baseline_result.txt
# Out:
# BLEU = 72.44, 87.6/76.6/67.6/61.0 (BP=0.999, ratio=0.999, hyp_len=8041, ref_len=8048)
